# %%
#Memanggil Library awal
from Extract import load_data 
from Transform import transform 

# --- TAHAP 1: EXTRACT ---
#Menentukan path dari dataset
path = "P2M3_Dianah_Salsha_Dilla_data_raw.csv" 

#Menjalankan fungsi df
df = load_data(path) # untuk mengeksekusi ekstraksi data

# --- TAHAP 2: TRANSFORM ---
#Menjalankan fungsi df terbaru
df_clean = transform(df) # untuk mengeksekusi pembersihan data

#Mengecek hasil akhir
df_clean.show(5)
# Out:
# +-------------------+------------+-------------+-------------+------------------+-------------+------------------+-----------+--------------+---------------------+-------------+------------+------------------+----------------+---------+-----------+--------------+--------------------------+-----------------------------+---------------+---------------+------------+------------------+---------------------+-------------------------+------------------+------------------------------+---------------------+-------------------+-----------------------+-----+---+----+--------------+
# ...

# %%
#Memanggil fungsi dari file load.py 
from Load import load_to_mongo

#Menyiapkan connection string dari MongoDB Atlas
koneksi_atlas = "mongodb+srv://dsdilla:kelinci123@cluster-dianah.pyh5xlc.mongodb.net/?retryWrites=true&w=majority" 

#Menentukan nama database dan collection di cloud Atlas
nama_db = "Hajj_Project" 
nama_tabel = "p2m3_data_clean"

#Menjalankan fungsi load dan mengirim data 'df_clean' ke cloud
load_to_mongo(df_clean, koneksi_atlas, nama_db, nama_tabel)
# Out:
# Data Berhasil Disimpan ke Atlas di tabel: p2m3_data_clean
